# %% [markdown]
# ## Analysing the website www.gotoauto.ca and scrap car name and price

# %% [markdown]
# #### Beautiful Soup is a Python library for pulling data out of HTML and XML files,So in this case i'm using it

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### The requests module allows you to send HTTP requests using Python

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Using requests library, we can fetch the content from the URL given and beautiful soup library helps to parse it and fetch the details the way we want

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# #### Selenium is an open-source web development tool used to automate web browsing functions

# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
page_no=1
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
content = requests.get("https://www.gotoauto.ca/inventory/?pg="+str(page_no),headers=headers)
soup = BeautifulSoup(content.content,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="NOODP,index,follow" name="robots"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="1" name="is_wp"/>
# <meta content="2" name="wp_page_id"/>
# <title>Go To Auto | Auto dealership in Regina</title>
# <meta content="Go To Auto, Regina auto dealer offers used and new cars. Great prices, quality service, financing and shipping options may be available, We Finance Bad Credit No Credit. Se Habla Espanol.Large Inventory of Quality Used Cars" name="description"/>
# ...

# %%
car_list=soup.find(class_="list")

# %%
car_list
# Out:
# <ul class="list">
# <li class="vehicle-item 1 mobile_visible" data-make="Audi" data-model="A4" data-year="2015" style="list-style: none;">
# <div class="div_saved_vehicle_14862358">
# <div class="vehicle_saved_item saved_vehicle_14862358" style="display:none;">
# <a class="vehicle_title_link" href="/inventory/view/14862358/2015-Audi-A4-Komfort-plus-S-line-Quattro-Sedan---Parking-sensors|Leather|Heated-seats|Sunroof">2015 Audi A4 Komfort plus S-line Quattro Sedan - Parking sensors|Leather|Heated seats|Sunroof</a>
# <a class="close close_me close_v_14862358" data-action="/" data-id="14862358" data-user="41533" style="cursor:pointer;">
# ...

# %%
car_list=soup.find_all(class_="list")

# %%
from selenium import webdriver

page_num =2
car_name=[]
price=[]
car_price=[]
car_detail={}

for current_page in range(1,page_num+1):
    driver = webdriver.Chrome(executable_path=r"/home/anirudh110/Downloads/chromedriver_linux64/chromedriver")

    driver.get('https://www.gotoauto.ca/inventory/?pg='+str(current_page))
    htmlPage_num='page'+str(current_page)+'.html'
    with open(htmlPage_num, 'w+') as f:
        f.write(driver.page_source)
        f.close()
    driver.close()
    with open(htmlPage_num) as fp:
        soup = BeautifulSoup(fp)
        
    for i in car_list:
        car_name_val = i.find("h4",attrs={'class':'name desc_l5'}).text
        car_name_valDel = car_name_val.replace('\t'," ").replace('\n'," ")
        final_carName = " ".join(car_name_valDel.split())
        car_name.append(final_carName)
        car_price.append(i.find("span",attrs={'class':'price'}).text)
# Out:
# <ipython-input-35-1f0b8d3a5049>:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=r"/home/anirudh110/Downloads/chromedriver_linux64/chromedriver")

# %%
car_details['Car Model']=car_name
car_details['Price']=car_price

import pandas as pd
car_data=pd.DataFrame(car_details)

# %%
car_data
# Out:
#             Car Model    Price
# 0        2015 Audi A4  $19,995
# 1        2015 Audi A4  $19,995
# 2        2014 Audi A5  $20,995
# 3        2017 Audi Q5  $28,995
# 4        2012 Audi S4  $22,995
# 5        2014 Audi S5  $29,995
# 6        2014 Audi S6  $34,995
# 7        2013 Audi S7  $34,995
# 8   2018 BMW 3-Series  $32,995
# 9   2015 BMW 3-Series  $29,995
# 10  2013 BMW 3-Series  $16,995
# 11  2015 BMW 4 Series  $34,995
# 12  2013 BMW 7-Series  $17,995
# 13        2012 BMW X1  $12,995
# 14        2017 BMW X4  $34,995
# 15  2018 Honda Accord  $28,995
# 16       2015 Audi A4  $19,995
# 17       2015 Audi A4  $19,995
# 18       2014 Audi A5  $20,995
# 19       2017 Audi Q5  $28,995
# 20       2012 Audi S4  $22,995
# 21       2014 Audi S5  $29,995
# 22       2014 Audi S6  $34,995
# 23       2013 Audi S7  $34,995
# 24  2018 BMW 3-Series  $32,995
# 25  2015 BMW 3-Series  $29,995
# 26  2013 BMW 3-Series  $16,995
# 27  2015 BMW 4 Series  $34,995
# 28  2013 BMW 7-Series  $17,995
# ...
